# %% [markdown]
# # Autores
# * Yu Hsiang Wang
# * Jesús Alfredo Cardenas Castillo

# %% [markdown]
# # SAMPLING TECHNIQUES
#
# It is one of the most important factors which determines the accuracy of your research/survey result. If anything goes wrong with your sample then it will be directly reflected in the final result.
#
#
# ### Population
# Population is the collection of the elements which has some or the other characteristic in common.
#
# ### Sampling
# Sampling is the process of selecting a sample.
#
# ### Sample
# Sample is the subset of the population.

# %% [markdown]
# There are two categories of sampling techniques:
# * Probability Sampling
# * Non - Probability Sampling
#
# The difference lies between the above two is whether the sample selection is based on randomization or not. With randomization, every element gets equal chance to be picked up and to be part of sample for study.

# %% [markdown]
# # Probability Sampling
#
# This category uses __randomization__ to make sure that every element of the population gets an equal chance to be part of the selected sample.
#
# There are 5 techniques in this category:

# %% [markdown]
# ## Simple Random Sampling
# Every element has an __equal chance__ of getting selected to be the part sample. It is used when we don’t have any kind of prior information about the target population.
#
# For example:
# Random selection of 20 students from class of 50 student. Each student has equal chance of getting selected. The probability of selection is 1/50.
# ![simple.png](attachment:simple.png)

# %% [markdown]
# ## Stratified Sampling
# This technique divides the elements of the population into __small subgroups__ (strata) based on the __similarity__ in such a way that the elements within the group are homogeneous and heterogeneous among the other subgroups formed. And then the elements are __randomly selected__ from each of these strata. We need to have prior information about the population to create subgroups.
# ![stratified.png](attachment:stratified.png)

# %% [markdown]
# ## Cluster Sampling
# The entire population is divided into __clusters or sections__ and then the clusters are randomly selected. All the elements of the cluster are used for sampling.
#
# Cluster sampling can be done in following ways:
#
# * ### Sing Stage Cluster Sampling
# The Entire cluster is selected randomly for sampling.
# ![cluster1.png](attachment:cluster1.png)
#
# * ### Two Stage Cluster Sampling
# First we randomly select clusters and then from those selected clusters we randomly select elements for sampling.
# ![cluster2.png](attachment:cluster2.png)

# %% [markdown]
# ## Systematic Sampling
# In this technique the selection of elements is __systematic__ and not random except the __first element__. All the elements are put together in a sequence first where each element has the equal chance of being selected.
#
# For a sample of size n, we divide our population of size N into subgroups of k elements.
#
# Then we select our __first element randomly__ from the first subgroup of k elements.
#
# To select other elements of sample, perform following:
# * The number of elements in each group is k = N/n
# * If our first element is n1 then second element = n1 + k and third element = n2 + k and so on...
# * Taking an example of N=20, n=5.
# * k = 20 / 5, k= 4.
# * Now we randomly select first element from the first subgroup.
# * n1 = 3, n2 = n1 + k = 3 + 4 = 7, n3 = n2 + k = 7 + 4 = 11.
# ![systematic.png](attachment:systematic.png)

# %% [markdown]
# ## Multi Stage Sampling
# It is a __combination__ of two or more methods described above.
#
# Population is divided into __multiple clusters__ and then these clusters are __further divided__ and grouped into various sub groups (strata) based on similarity.
#
# One or more clusters can be __randomly selected__ from each stratum. This process continues until the cluster can’t be divided anymore.
#
# For example country can be divided into states, cities, urban and rural and all the areas with similar characteristics can be merged together to form a strata.
# ![multi.png](attachment:multi.png)

# %% [markdown]
# # Non-Probability Sampling
#
# Esta técnica depende de la capacidad del investigador para seleccionar elementos para una muestra, no depende de la probabilidad sino de las condiciones que permiten hacer el muestreo (acceso o disponibilidad, conveniencia, etc); son seleccionadas con mecanismos informales y no aseguran la total representación de la población.
# Hay situaciones en que es más conveniente usar un muestreo no probabilístico, por ejemplo cuando vamos a hacer
# estudios de casos, de poblaciones heterogéneas, o en estudios que son dirigidos a poblaciones y grupos muy específicos donde interesa una cuidadosa y controlada selección de sujetos con determinadas características.
#
#
# Existen 4 ramas dentro de esta tecnica:
#
#
# $\textbf{Convenience Sampling (Muestreo de conveniencia)}$
#
# El muestreo de conveniencia es un tipo de muestreo en el que la primera fuente de datos primaria disponible se utilizará para la investigación sin requisitos adicionales. En otras palabras, este método de muestreo consiste en buscar a los participantes en donde se puedan encontrar, y por lo general, donde sea conveniente. En el muestreo de conveniencia no se identificaron criterios de inclusión antes de la selección de los sujetos. Todos los sujetos están invitados a participar.
# Este método se utiliza cuando la disponibilidad de la muestra es rara y también costosa. Así que en base a la conveniencia se seleccionan muestras.
#
# En su forma básica, el método de muestreo de conveniencia se puede aplicar deteniendo a personas al azar en la calle y haciendo preguntas al cuestionario.
#
#     Ventajas:
#
#     -Simplicidad de muestreo y facilidad de investigación.
#
#     -Útil para estudios piloto y generación de hipótesis.
#
#     -La recopilación de datos se puede facilitar en un corto período de tiempo.
#
#     -Más barato para implementar métodos alternativos de muestreo.
#
#     Desventajas:
#
#     -Altamente vulnerable a los sesgos e influencias de selección más allá del control del investigador.
#
#     -Alto nivel de error de muestreo.
#
#     -Los estudios que utilizan muestreo de conveniencia tienen poca credibilidad.

# %% [markdown]
# $\textbf{Purposive Sampling (Muestreo intencional)}$
#
# También conocido como Juzgado, es una técnica de muestreo en la que el investigador se basa en su propio juicio al elegir a miembros de la población para participar en el estudio, se produce cuando los elementos seleccionados para la muestra son elegidos por el criterio del investigador. Los investigadores a menudo creen que pueden obtener una muestra representativa utilizando un buen juicio, lo que resultará en un ahorro de tiempo y dinero.
#
# En el muestreo intencional, se debe utilizar el juicio personal para elegir casos que ayuden a responder preguntas de investigación o lograr objetivos de investigación.
#
# Según el tipo de casos, el muestreo intencional se puede dividir en las siguientes seis categorías:
#
# Caso típico. Explica casos que son medios y normales.
# Caso extremo o desviado. Obtención de muestras de casos que se perciben como inusuales o raros, como explorar las razones del fracaso corporativo al entrevistar a ejecutivos despedidos por accionistas.
#
#
#     -El muestreo de casos críticos se enfoca en casos específicos que son dramáticos o muy importantes.
#
#     -El muestreo heterogéneo o de variación máxima se basa en el criterio del investigador para seleccionar participantes con características diversas. Esto se hace para asegurar la presencia de máxima variabilidad dentro de los datos primarios.
#
#     -El muestreo homogéneo se centra en un subgrupo particular en el que todos los miembros de la muestra son similares, como una ocupación o nivel en particular en la jerarquía de una organización.
#
#     -El muestreo teórico es un caso especial de muestreo intencional que se basa en un método inductivo de teoría fundamentada.
#
# Por ejemplo: si queremos comprender el pensamiento de las personas que están interesadas en obtener un título de maestría, entonces el criterio de selección sería "¿Está interesado en obtener una maestría en ...?"
#
# Todas las personas que respondan con un "No" serán excluidas de nuestra muestra.
#
#     Ventajas:
#
#     -El muestreo intencional es uno de los métodos de muestreo más rentables y eficientes.
#
#     -El muestreo intencional puede ser el único método apropiado disponible si solo hay un número limitado de fuentes de datos primarios que pueden contribuir al estudio
#
#     -Esta técnica de muestreo puede ser eficaz para explorar situaciones antropológicas en las que el descubrimiento de un significado puede beneficiarse de un enfoque intuitivo.
#
#     Desventajas:
#
#     -Vulnerabilidad a los errores de juicio del investigador.
#
#     -Bajo nivel de confiabilidad y altos niveles de sesgo.
#
#     -Incapacidad para generalizar los resultados de la investigación.

# %% [markdown]
# $\textbf{Quota Sampling (Muestreo de cuotas)}$
#
# Este tipo de muestreo depende de algún estándar preestablecido, es un método de muestreo para recopilar datos representativos de un grupo. La aplicación del muestreo por cuotas garantiza que el grupo de muestra represente ciertas características de la población elegida por el investigador.
#
# El muestreo de cuotas se puede dividir en dos grupos: controlado y no controlado.
#
#     -El muestreo de cuotas controlado implica la introducción de ciertas restricciones para limitar la selección de muestras por parte del investigador.
#
#     -El muestreo de cuota no controlado se asemeja al método de Convenience Sampling (muestreo de conveniencia) de una manera que el investigador puede elegir libremente los miembros del grupo de muestra de acuerdo con su voluntad.
#
#
# Ejemplo:
#
# Asumamos que su objetivo de investigación es evaluar el impacto de las diferentes culturas en la motivación de los empleados. Debe evaluar la efectividad de las herramientas de motivación de los empleados teniendo en cuenta las diferencias de género entre la fuerza laboral.
#
# El muestreo de cuotas se puede aplicar de la siguiente manera:
#
# 1. División de la población en grupos específicos. Los empleados como marco de muestreo deben dividirse en los siguientes cinco grupos de acuerdo con su fondo cultural:
#
#     -Europeo
#     -Asia (India)
#     -Asiático (China)
#     -Negro (africano)
#     -Otro
#
# 2. Calcular una cuota para cada grupo. Su supervisor confirma que para alcanzar los objetivos de la investigación, serían apropiados 30 representantes de cada grupo y el tamaño total de la muestra de 150 encuestados.
#
# 3. Determinar las condiciones específicas que se deben cumplir y la cuota en cada grupo
#
# Ambos sexos, hombres y mujeres deben estar representados por igual en su grupo de muestra. Esta es una condición importante que debe ser satisfecha. En consecuencia, se reclutan 15 hombres y 15 mujeres de cada grupo.
#
# La aplicación del muestreo por cuotas garantiza que el grupo de muestra represente ciertas características de la población elegida por el investigador. En el ejemplo anterior, una representación igual de ambos sexos, hombres y mujeres, ha sido elegida como una característica importante del muestreo.
#
#
#     Ventajas:
#
#     -El muestreo de cuotas surge como una opción atractiva ya que la recolección de datos primarios se puede hacer en un tiempo más corto.
#
#     -La aplicación del muestreo de cuotas puede ser rentable.
#
#     -El muestreo por cuotas no depende de la presencia de los marcos de muestreo. En ocasiones en las que no existe un marco de muestreo adecuado, el muestreo por cuotas puede ser la única opción apropiada disponible.
#
#     Desventajas:
#
#     -Igual que otros métodos de muestreo no probabilístico, en el muestreo por cuotas no es posible calcular el error de muestreo y la proyección de los resultados de la investigación a la población total es arriesgada.
#
#     -Si bien esta técnica de muestreo puede ser muy representativa de las características que definen la cuota, otras características importantes pueden estar representadas de manera desproporcionada en el grupo final de la muestra.
#
#     -Existe un gran potencial para el sesgo del investigador y la calidad del trabajo puede sufrir debido a la incompetencia del investigador y / o la falta de experiencia.

# %% [markdown]
# $\textbf{Snowball Sampling (Muestreo de referencia)}$
#
# Esta técnica se utiliza en situaciones en las que la población es completamente desconocida y rara.
#
# Por lo tanto, tomaremos la ayuda del primer elemento que seleccionamos para la población y le pediremos que recomiende otros elementos que se ajusten a la descripción de la muestra necesaria. Así que esta técnica de referencia continúa, aumentando el tamaño de la población como una bola de nieve.
#
# Por ejemplo, si está estudiando el nivel de satisfacción del cliente de un club privado, le resultará cada vez más difícil encontrar fuentes de datos primarias a menos que un miembro esté dispuesto a proporcionarle contactos de otros miembros.
#
# Este método de muestreo involucra fuentes de datos primarias que nominan a otras fuentes de datos primarias potenciales para ser utilizadas en la investigación. En otras palabras, el método de muestreo de la bola de nieve se basa en las referencias de los sujetos iniciales para generar sujetos adicionales. Por lo tanto, al aplicar este método de muestreo, los miembros del grupo de muestra se reclutan a través de la cadena de referencia.
#
# Existen 3 patrones en esta tecnica:
#
#     1. Muestreo lineal. La formación de un grupo de muestra comienza con un solo sujeto y el sujeto proporciona solo una referencia.
#
#     2. Muestreo exponencial no discriminativo. El primer tema reclutado para el grupo de muestra proporciona múltiples referencias.
#
#     Muestreo exponencial discriminativo. Los sujetos dan múltiples referencias, sin embargo, solo uno nuevo es reclutado entre ellos.
#
# La aplicación del muestreo de bolas de nieve comprende las siguientes etapas:
#
#     -Establecer un contacto con uno o dos casos iniciales desde el marco muestral. Esta etapa suele ser la más difícil.
#
#     -Solicitar los casos iniciales para identificar más casos.
#
#     -Pedir nuevos casos para identificar otros casos (y así sucesivamente)
#
#
#     Ventajas:
#
#     -La capacidad de reclutar poblaciones ocultas.
#
#     -La posibilidad de recopilar datos primarios de manera rentable.
#
#     -Los estudios se pueden completar en un corto período de tiempo.
#
#     -Se requiere muy poca planificación para iniciar el proceso de recolección de datos primarios
#
#     Desventajas:
#
#     -Sobremuestrear una red particular de pares puede llevar a sesgos.
#
#     -Dificultad para iniciar el encadenamineto.
#
#     -No hay garantía sobre la representatividad de las muestras.
#
#     -No es posible determinar el error de muestreo y hacer inferencias estadísticas de la muestra a la población debido a la ausencia de una selección aleatoria de muestras.

# %% [markdown]
# # Algoritmos de Scikit-Learn para generar muestras
# Ejemplos para algoritmos de clasificación y regresión.
#
# ## Classification Test Problems
# Classification is the problem of assigning labels to observations.
#
# ### Blobs Classification Problem
# The __make_blobs()__ function can be used to generate blobs of points with a Gaussian distribution.
#
# You can control how many blobs to generate and the number of samples to generate, as well as a host of other properties.
#
# The problem is suitable for __linear classification problems__ given the linearly separable nature of the blobs.
#
# The example below generates a 2D dataset of samples with __three blobs__ as a multi-class classification prediction problem. Each observation has __two inputs__ and 0, 1, or 2 class values.

# %%
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

#FUNCIÓN MAKE BLOBS
#-------------------------------------------------------------------------
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2)
#-------------------------------------------------------------------------

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    
pyplot.show()

# %% [markdown]
# ### Moons Classification Problem
# The __make_moons()__ function is for binary classification and will generate a swirl(Remolino) pattern, or two moons.
#
# You can control how noisy the moon shapes are and the number of samples to generate.
#
# This test problem is suitable for algorithms that are capable of learning __nonlinear class boundaries__.
#
# The example below generates a moon dataset with moderate noise.

# %%
from sklearn.datasets import make_moons
from matplotlib import pyplot
from pandas import DataFrame

#FUNCIÓN MAKE MOON
#------------------------------------------------------------
# generate 2d classification dataset
X, y = make_moons(n_samples=100, noise=0.1)
#------------------------------------------------------------

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    
pyplot.show()

# %% [markdown]
# ### Circles Classification Problem
#
# The __make_circles()__ function generates a binary classification problem with datasets that fall into concentric circles.
#
# Again, as with the moons test problem, you can control the amount of noise in the shapes.
#
# This test problem is suitable for algorithms that can learn __complex non-linear manifolds__.
#
# The example below generates a circles dataset with some noise.

# %%
from sklearn.datasets import make_circles
from matplotlib import pyplot
from pandas import DataFrame

#MAKE CIRCLE
#------------------------------------------------------------------
# generate 2d classification dataset
X, y = make_circles(n_samples=100, noise=0.05)
#------------------------------------------------------------------

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    
pyplot.show()

# %% [markdown]
# ## Regression Test Problems
# The __make_regression()__ function will create a dataset with a __linear relationship__ between inputs and the outputs.
#
# You can configure the number of samples, number of input features, level of noise, and much more.
#
# This dataset is suitable for algorithms that can learn a __linear regression function__.
#
# The example below will generate 100 examples with one input feature and one output feature with modest noise.

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot

#MKE REGRESION--------------------------------------------------------------
# generate regression dataset
X, y = make_regression(n_samples=100, n_features=1, noise=0.1)
#---------------------------------------------------------------------------

# plot regression dataset
pyplot.scatter(X,y)
pyplot.show()

# %% [markdown]
# # Implementación en Python
#
# ## Probability Sampling

# %%
import random

#Generamos 50 números enteros aleatorios entre 0 y 100 (Sin repeticiones)
datos = random.sample(range(101), 50)

print(datos)
# Out:
# [40, 12, 75, 37, 66, 50, 61, 63, 26, 91, 55, 78, 100, 65, 79, 4, 41, 88, 96, 59, 16, 25, 86, 68, 89, 27, 24, 82, 84, 62, 3, 57, 0, 80, 21, 46, 81, 14, 20, 53, 19, 56, 67, 69, 42, 32, 71, 38, 9, 97]

# %% [markdown]
# ### Simple Random Sampling

# %%
import copy

posiciones = []
simple_random_sampling = []
cont = 0

#Elegimos 20 números dentro de la lista de manera aleatoria
while cont < 20:
    n = random.randint(0,49)
    if n not in posiciones:
        posiciones.append(n)
        cont += 1

simple_random_sampling = [datos[i] for i in posiciones]


#Números seleccionados de manera aleatoria
print()
print("20 Números seleccionados de manera aleatoria")
print(simple_random_sampling)
# Out:
# 20 Números seleccionados de manera aleatoria
# [96, 63, 53, 26, 9, 82, 69, 68, 32, 21, 0, 61, 59, 66, 4, 20, 46, 84, 97, 81]

# %% [markdown]
# ### Stratified Sampling
# Ahora seleccionaremos 10 números pares y 10 números impares de manera aleatoria

# %%
pares = []
impares = []

for n in datos:
    if n % 2 == 0:
        pares.append(n)
    else:
        impares.append(n)

print("Pares:", pares)
print("Impares:", impares)
# Out:
# Pares: [40, 12, 66, 50, 26, 78, 100, 4, 88, 96, 16, 86, 68, 24, 82, 84, 62, 0, 80, 46, 14, 20, 56, 42, 32, 38]
# Impares: [75, 37, 61, 63, 91, 55, 65, 79, 41, 59, 25, 89, 27, 3, 57, 21, 81, 53, 19, 67, 69, 71, 9, 97]

# %%
cont = 0
pares_aleatorios = []
impares_aleatorios = []

#10 pares aleatorios
while cont < 10:
    n = random.randint(0,len(pares)-1)
    if pares[n] not in pares_aleatorios:
        pares_aleatorios.append(pares[n])
        cont += 1
        
cont = 0
#10 impares aleatorios
while cont < 10:
    n = random.randint(0,len(impares)-1)
    if impares[n] not in impares_aleatorios:
        impares_aleatorios.append(impares[n])
        cont += 1
        
print("10 Pares aleatorios:", pares_aleatorios)
print("10 Impares aleatorios:", impares_aleatorios)
# Out:
# 10 Pares aleatorios: [88, 68, 80, 14, 86, 100, 42, 16, 66, 78]
# 10 Impares aleatorios: [21, 19, 41, 97, 79, 57, 53, 65, 63, 59]

# %% [markdown]
# ## Non - Probability Sampling
#
# $\textbf{Ejemplo practico}$
#
# En este ejemplo se tratara de predecir los valores de la felicidad humana respecto a sus riquezas, en este ejemplo solo serán tomadas en cuenta las localidades que hablen el idioma Español e Ingles. Debido a que el grupo de personas que realizara las encuestas solo saben estos dos idiomas.

# %%
#Obtenemos nuestra raiz de direccion
import os
datapath = os.path.join("datasets", "lifesat", "")
os.getcwd()
# Out:
# '/home/alopolisia/Documentos/Octavo Cuatri/Mineria de Datos/Ejemplos en Clase/Investigacion'

# %% [markdown]
# En este estudio se pretende conocer la relación entre la felicidad y el dinero, ademas con la restricción del idioma, debido a que se quiere saber si este factor puede llegar a influir, es por eso que solo se tomaran muestras de las localidades que hablen el idioma Español e Ingles para encontrar alguna relación.

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"] == "TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita, left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    
    #Borrar los paises que no hablan Inglés ni Español
    remove_indices = [0,2,3,4,5,7,8,9,10,11,12,14,15,16,17,19,20,21,22,24,25,26,27,28,29,30,31,33,34,35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
import pandas as pd
#Cargamos los datos
oecd_bli = pd.read_csv(datapath+"oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv", thousands=',', delimiter='\t', encoding='latin1', na_values="n/a")
    
#Preparamos los datos en el formato
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
country_stats
# Out:
#                GDP per capita  Life satisfaction
# Country
# United States       55805.204                7.2
# Mexico               9009.280                6.7
# Chile               13340.905                6.7
# Spain               25864.721                6.5
# New Zealand         37044.891                7.3
# Canada              43331.961                7.3

# %% [markdown]
# En la tabla anterior se muestran las localidades que hablan dichos idiomas, con estas 6 localidades se realizaran los estudios.

# %%
# to plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

#Visualizamos los datos en una grafica
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# %% [markdown]
# En este caso se aplicara la regresión, es por eso que necesitaremos encontrar la ecuación lineal de dichos datos para obtener una aproximación.
#
# La formula de una ecuación lineas es la siguiente:
#
#         y = ax + b
#
# Es necesario aplicar las siguientes formulas para encontrar los valores de las variables necesarias.
#
#
# $a=\binom{n\sum xy - \sum x\sum y}{n\sum x^{2} - (\sum x)^{2}}$
#
#
#
# $b = \binom{\sum y-a\sum x}{n}$

# %%
n = 6

x = country_stats['GDP per capita'].tolist()
sumatoriaX = sum(x)

y = country_stats['Life satisfaction'].tolist()
sumatoriaY = sum(y)

xy = [1,2,3,4,5,6]
for i in range(n):
    xy[i] = x[i]*y[i]
    
sumatoriaXY = sum(xy)

for i in range(n):
    x[i] = x[i]*x[i]
sumatoriaX2 = sum(x)

print("Sumatoria de X = ",sumatoriaX)
print("Sumatoria de Y = ",sumatoriaY)
print("Sumatoria de X^2 = ",sumatoriaX2)
print("Sumatoria de XY = ",sumatoriaXY)
# Out:
# Sumatoria de X =  184396.962
# Sumatoria de Y =  41.699999999999996
# Sumatoria de X^2 =  7292334251.534285
# Sumatoria de XY =  1306415.4144000001

# %% [markdown]
# Una vez que sabemos los valores de las respectivas sumatorias, procederemos a remplazarlas en la ecuación.

# %%
a = (n*sumatoriaXY - sumatoriaX * sumatoriaY)/(n*sumatoriaX2-(sumatoriaX * sumatoriaX))
print("Valor de A: ",a)
# Out:
# Valor de A:  1.5293555270860004e-05

# %%
b = (sumatoriaY - a * sumatoriaX)/n
print("Valor de B: ",b)
# Out:
# Valor de B:  6.479985811645721

# %%
print("y = ",a,"x + ",b)
# Out:
# y =  1.5293555270860004e-05 x +  6.479985811645721

# %%
def funcion(x):
    return a*x+b

# %%
#Visualizamos los datos en una grafica
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
x = country_stats['GDP per capita'].tolist()
plt.plot(x, [funcion(i) for i in x])
plt.show()

# %% [markdown]
# # Referencias
# * BrownLee, J. (2017, December 04). How to Generate Test Datasets in Python with scikit-learn. Retrieved February 03, 2019, from https://machinelearningmastery.com/generate-test-datasets-python-scikit-learn/
# * Singh, S. (2018, July 26). Sampling Techniques – Towards Data Science. Retrieved January 29, 2019, from https://towardsdatascience.com/sampling-techniques-a4e34111d808?gi=a654bf38d90d
# * M. (2015, October 16). Ecuación de correlación lineal. Retrieved February 3, 2019, from https://www.youtube.com/watch?v=fNeXC8d5En8
# * R. (n.d.). Convenience sampling - Research Methodology. Retrieved February 3, 2019, from https://research-methodology.net/sampling-in-primary-data-collection/convenience-sampling/
# * R. (n.d.). Purposive sampling - Research Methodology. Retrieved February 3, 2019, from https://research-methodology.net/sampling-in-primary-data-collection/purposive-sampling/
# * R. (n.d.). Quota sampling - Research Methodology. Retrieved February 3, 2019, from https://research-methodology.net/sampling-in-primary-data-collection/quota-sampling/
# * R. (n.d.). Snowball sampling - Research Methodology. Retrieved February 3, 2019, from https://research-methodology.net/sampling-in-primary-data-collection/snowball-sampling/
